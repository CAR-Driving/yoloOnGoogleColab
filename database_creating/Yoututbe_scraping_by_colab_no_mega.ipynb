# %% [markdown]
# <a href="https://colab.research.google.com/github/CAR-Driving/yoloOnGoogleColab/blob/master/database_creating/Yoututbe_scraping_by_colab_no_mega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This colab page is related to this question:
#
# https://stackoverflow.com/questions/64736227/yoututbe-scraping-by-colab?noredirect=1#comment114495750_64736227

# %% [markdown]
#  The question is :
#
#  ---------------------------------
#
# I need to scrap car type video from YouTube by some tags like [this list][1] in Google Colab :
#
# ```
# Abarth
# AC
# Acura
# Adam
# Adler
# AEC
# Aero
# Aixam
# Albion
# ```
# SO i have tried these two code to find the video tag ( for example tag='Peugeot') in google colab:
#
#
# ```
# !pip install youtube-search-python
# from youtubesearchpython import SearchVideos
#
# search = SearchVideos("NoCopyrightSounds", offset = 1, mode = "json", max_results = 20)
#
# print(search.result())
# ```
# and
#
# ```
#
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt
#
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt'  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch2000:" "Ford Festiva" >> ford_video_list.txt
#
# !echo '*****End of test 1 ******'
#
# ```
# But by trying this code it don't showing any result:
# ```
# import urllib.request
# from bs4 import BeautifulSoup
#
# textToSearch = 'python tutorials'
# query = urllib.parse.quote(textToSearch)
# url = "https://www.youtube.com/results?search_query=" + query
# response = urllib.request.urlopen(url)
# html = response.read()
# soup = BeautifulSoup(html, 'html.parser')
# for vid in soup.findAll(attrs={'class':'yt-uix-tile-link'}):
#     if not vid['href'].startswith("https://googleads.g.doubleclick.net/"):
#         print('https://www.youtube.com' + vid['href'])
# ```
# So, i guess the class name is not correct!, and i asked here for debugging it.
#
# Thanks.
#
#   [1]: https://github.com/spectrico/vehicle-recognition-api-yolov4-python/blob/master/labels-makes.txt

# %% [markdown]
# # The main function for scrapin the car type video from the **car_type_label.txt** file and download data by youtube-dl comand for each line of that txt file

# %% [markdown]
# # @title
# # conect to [Mega.z](https://mega.nz/) cloud for storage files based ot this page:
#
# https://colab.research.google.com/github/sudo-ken/Mega-to-Google-Drive/blob/master/Transfer_files_from_Mega_to_Google_Drive.ipynb#scrollTo=Vgh1xlQYGZCO

# %%
#@title
# @markdown <center><h3>Input Your Mega ID</h3></center><br>
from functools import wraps
import errno
import os
import signal
import subprocess
import shlex


class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


if not os.path.exists("/root/.ipython/ocr.py"):
    from subprocess import run
    from shlex import split

    shellCmd = "wget -qq https://raw.githubusercontent.com/biplobsd/OneClickRun/master/res/ocr.py \
                    -O /root/.ipython/ocr.py"
    run(split(shellCmd))
from ocr import runSh

@timeout(10)
def runShT(args):
    return runSh(args, output=True)


# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
else:
    # !pkill mega-cmd

# INPUT YOUR MEGA ID

USERNAME = 'kayeyoc231@llubed.com'  # @param {type:"string"}
PASSWORD = "ss123456"  # @param {type:"string"}
if not (USERNAME == "" or PASSWORD == ""):
    try:
        runShT(f"mega-login {USERNAME} {PASSWORD}")
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")
# @markdown *After signing in, use the above cell(Main Cell) to transfer files from Mega to GDrive using the transfer quota of your Mega Pro Account*

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !mkdir "/content/gdrive/My Drive/yolo_car_database/"

# !cp /content "gdrive/My Drive/yolo_car_databe"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# mkdir: cannot create directory ‘/content/gdrive/My Drive/yolo_car_database/’: File exists

# %%
# !pip install youtube-dl 
# !apt install python3-distutils   
# !pip install mega.py
# !apt install python3-distutils  -y

# %cd '/content/'
# !git clone https://github.com/jeroenmeulenaar/python3-mega.git
# !(cd python3-mega; pip install urlobject pycrypto)

# import os
# os.chdir('python3-mega')
# from mega import Mega
# os.chdir('../')
# m = Mega.from_ephemeral()

# !git clone https://github.com/odwyersoftware/mega.py
# %cd mega.py
# !python setup.py install
# %cd '/content/'
# !rm -rf '/content/yoloOnGoogleColab'
# !git clone https://github.com/CAR-Driving/yoloOnGoogleColab
# !rm -rf '/content/yolo_car_database'
# !mkdir '/content/yolo_car_database'
# %cd '/content/yolo_car_database'
# !echo 't' >> t.txt

from subprocess import Popen, PIPE
import shlex
import errno, os

from subprocess import Popen, PIPE
import shlex

import re
from distutils.dir_util import copy_tree

# copy subdirectory example
fromDirectory = '/content/yolo_car_database/'
toDirectory = '/content/gdrive/My Drive/yolo_car_database/'

# copy_tree(fromDirectory, toDirectory)
def uplaod_mega_nz(root,cloude='google_drive',title1=''):
 if (cloude=='mega'):
   from mega import Mega
   mega = Mega()
   email = 'woraqofa@ivyandmarj.com'
   password = 'feripas800@wgraj.com'
   m = mega.login(email, password)
   # login using a temporary anonymous account
   m = mega.login()
   quota = m.get_quota()
   # specify unit output kilo, mega, gig, else bytes will output
   space = m.get_storage_space(kilo=True)
   m.create_folder('yolo_car_database/'+title1+'/')
   folder = m.find('yolo_car_database/'+title1+'/')
   # m.upload('myfile.doc', folder[0])
   for path, subdirs, files in os.walk( root):
      for name in files:
          m.upload(os.path.join(path, name), folder[0])
   # public_exported_web_link = m.export('myfile.doc')
   # public_exported_web_link = m.export('my_mega_folder/my_sub_folder_to_share')
 if (cloude=='google_drive'):
     run_command('mkdir '+root+'/')
     copy_tree(root,'/content/gdrive/My Drive/yolo_car_database/' + title1 + '/')

def run_command(cmd):
    with Popen(shlex.split(cmd), stdout=PIPE, bufsize=1, universal_newlines=True) as p:
        while True:
            line = p.stdout.readline()
            if not line:
                break
            print(line)    
        exit_code = p.poll()
    return exit_code

def Youtube_download_video(command):
    # command_title=re.split('([^a-zA-Z0-9])',command)
    command_title_1 = re.split('([^a-zA-Z0-9])', command)
    command_title = ''.join(command_title_1)
    command_title = command_title.replace(" ", "_")
    command_title = command_title.replace("'", "_")
    command_title = command_title.replace("\n", "")
    command_title = command_title.replace("\t", "")

    # call_args = ' youtube-dl --match-title ' + ' "'+command_title_1[0]+ '" ' + '"ytsearch10":'+'"'+command+ '" '+"--external-downloader-args   '-ss 00:00:03 -t 00:03:08' --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4'"
    call_args = ' youtube-dl --match-title ' + ' "'+command_title_1[0]+ '" ' + '"ytsearch15":'+'"'+command+ '" '+"--external-downloader-args   '-ss 00:00:03 -t 00:03:08' --write-info-json --write-annotation --write-thumbnail --write-sub -f 'best[ext=mp4,height=720]+best[filesize<50M' "

    # call_args = call_args.split() # because call takes a list of strings
    # print (call_args)
    # call(call_args)
    # os.chdir("/content/yolo_car_database")
    # run_command('cd "/content/yolo_car_database"') 
    # run_command(call_args)
    # os.system("cp --recursive '/content/yolo_car_database' '/content/gdrive/My Drive/yolo_car_databe")
    # os.system('pwd && ls ')
    # copy_tree(fromDirectory, toDirectory)
    # p = Popen(shlex.split(call_args), bufsize=1, universal_newlines=True)
    run_command('mkdir /content/yolo_car_database/'+command_title)
    
    os.chdir( '/content/yolo_car_database/'+command_title+'/')
    run_command(call_args) 
    # copy_tree('/content/yolo_car_database/'+command_title+'/', '/content/gdrive/My Drive/yolo_car_database/'+command_title+'/')
    uplaod_mega_nz('/content/yolo_car_database/'+command_title+'/','google_drive',command_title)
    try:
        # call(call_args)
        # run_command('mkdir /content/yolo_car_database/'+command_title)
        # os.chdir( '/content/yolo_car_database/'+command_title+'/')
        # run_command(call_args) 
        # copy_tree('/content/yolo_car_database/'+command_title+'/', toDirectory)

        # print (call_args)
        pp=0
        
    except OSError as e: # this would be "except OSError, e:" before Python 2.6
        if e.errno != errno.ENOENT: # errno.ENOENT = no such file or directory
            raise # re-raise exception if a different error occurred
 
    # return p.poll()

# !wget https://github.com/spectrico/car-make-model-classifier-yolo3-python/blob/master/labels.txt

i=0
for line in open('/content/yoloOnGoogleColab/car_type_label.txt','r').readlines():
    print (line)
    Youtube_download_video(line)
    i=i+1
# !cp '/content/yolo_car_database' "gdrive/My Drive/yolo_car_databe"
# Out:
# Streaming output truncated to the last 5000 lines.
# [download]  31.7% of 121.47MiB at 765.38KiB/s ETA 01:52
#
# [download]  31.7% of 121.47MiB at  1.89MiB/s ETA 00:44
#
# [download]  31.7% of 121.47MiB at  3.43MiB/s ETA 00:24
#
# [download]   0.0% of 5.98MiB at  1.37MiB/s ETA 00:04
#
# [download]   0.1% of 5.98MiB at  3.04MiB/s ETA 00:01
#
# [download]   0.2% of 5.98MiB at  6.18MiB/s ETA 00:00
#
# [download]   0.5% of 5.98MiB at  2.29MiB/s ETA 00:02
#
# [download]   1.0% of 5.98MiB at  2.59MiB/s ETA 00:02
#
# [download]   2.1% of 5.98MiB at  3.59MiB/s ETA 00:01
#
# [download]   4.2% of 5.98MiB at  5.36MiB/s ETA 00:01
#
# [download]   8.3% of 5.98MiB at  8.73MiB/s ETA 00:00
#
# [download]  16.7% of 5.98MiB at 14.42MiB/s ETA 00:00
#
# [download]  33.4% of 5.98MiB at 24.63MiB/s ETA 00:00
#
# [download]  66.9% of 5.98MiB at 41.10MiB/s ETA 00:00
#
# [download] 100.0% of 5.98MiB at 52.88MiB/s ETA 00:00
#
# [download] 100% of 5.98MiB in 00:00
#
# [ffmpeg] Merging formats into "2017 Honda Civic - Review and Road Test-K6kyAeAozBs.mp4"
#
# Deleting original file 2017 Honda Civic - Review and Road Test-K6kyAeAozBs.f137.mp4 (pass -k to keep)
#
# Deleting original file 2017 Honda Civic - Review and Road Test-K6kyAeAozBs.f140.m4a (pass -k to keep)
#
# [download] Downloading video 8 of 10
#
# [youtube] I_1FPzRtLMA: Downloading webpage
#
# [info] Writing video description metadata as JSON to: Battle of the Best Selling Cars - 2020 Honda Civic vs Toyota Corolla-I_1FPzRtLMA.info.json
#
# [youtube] I_1FPzRtLMA: Downloading thumbnail ...
#
# [youtube] I_1FPzRtLMA: Writing thumbnail to: Battle of the Best Selling Cars - 2020 Honda Civic vs Toyota Corolla-I_1FPzRtLMA.webp
#
# [download] Destination: Battle of the Best Selling Cars - 2020 Honda Civic vs Toyota Corolla-I_1FPzRtLMA.f137.mp4
#
#
#
# [download]   0.0% of 193.22MiB at Unknown speed ETA Unknown ETA
#
# [download]   0.0% of 193.22MiB at Unknown speed ETA Unknown ETA
#
# [download]   0.0% of 193.22MiB at Unknown speed ETA Unknown ETA
#
# [download]   0.0% of 193.22MiB at Unknown speed ETA Unknown ETA
#
# [download]   0.0% of 193.22MiB at  2.34MiB/s ETA 01:23
#
# [download]   0.0% of 193.22MiB at  2.71MiB/s ETA 01:11
#
# [download]   0.1% of 193.22MiB at  3.67MiB/s ETA 00:52
#
# [download]   0.1% of 193.22MiB at  5.48MiB/s ETA 00:35
#
# [download]   0.3% of 193.22MiB at  8.95MiB/s ETA 00:21
#
# [download]   0.5% of 193.22MiB at 14.79MiB/s ETA 00:13
#
# [download]   1.0% of 193.22MiB at 25.07MiB/s ETA 00:07
#
# [download]   2.1% of 193.22MiB at 42.57MiB/s ETA 00:04
#
# [download]   4.1% of 193.22MiB at 55.64MiB/s ETA 00:03
#
# [download]   5.0% of 193.22MiB at 54.26MiB/s ETA 00:03
#
# [download]   5.0% of 193.22MiB at 586.86KiB/s ETA 05:23
#
# [download]   5.0% of 193.22MiB at  1.53MiB/s ETA 02:00
#
# [download]   5.0% of 193.22MiB at  3.34MiB/s ETA 00:55
#
# [ffmpeg] Merging formats into "Can my Honda Civic Keep Up LET'S GO _ POV Canyon Drive-1PPe_B5E7Ag.mp4"
#
# Deleting original file Can my Honda Civic Keep Up LET'S GO _ POV Canyon Drive-1PPe_B5E7Ag.f299.mp4 (pass -k to keep)
#
# Deleting original file Can my Honda Civic Keep Up LET'S GO _ POV Canyon Drive-1PPe_B5E7Ag.f140.m4a (pass -k to keep)
#
# [download] Finished downloading playlist: Honda	Civic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0d4cbe25b4c7> in <module>()
#     121 for line in open('/content/yoloOnGoogleColab/car_type_label.txt','r').readlines():
#     122     print (line)
# --> 123     Youtube_download_video(line)
#     124     i=i+1
#     125 # !cp '/content/yolo_car_database' "gdrive/My Drive/yolo_car_databe"
#
# <ipython-input-5-0d4cbe25b4c7> in Youtube_download_video(command)
#      99     run_command(call_args)
#     100     # copy_tree('/content/yolo_car_database/'+command_title+'/', '/content/gdrive/My Drive/yolo_car_database/'+command_title+'/')
# --> 101     uplaod_mega_nz('/content/yolo_car_database/'+command_title+'/','google_drive',command_title)
#     102     try:
#     103         # call(call_args)
#
# <ipython-input-5-0d4cbe25b4c7> in uplaod_mega_nz(root, cloude, title1)
#      62  if (cloude=='google_drive'):
#      63      run_command('mkdir '+root+'/')
# ---> 64      copy_tree(root,'/content/gdrive/My Drive/yolo_car_database/' + title1 + '/')
#      65
#      66 def run_command(cmd):
#
# /usr/lib/python3.6/distutils/dir_util.py in copy_tree(src, dst, preserve_mode, preserve_times, preserve_symlinks, update, verbose, dry_run)
#     174             copy_file(src_name, dst_name, preserve_mode,
#     175                       preserve_times, update, verbose=verbose,
# --> 176                       dry_run=dry_run)
#     177             outputs.append(dst_name)
#     178
#
# /usr/lib/python3.6/distutils/file_util.py in copy_file(src, dst, preserve_mode, preserve_times, update, link, verbose, dry_run)
#     149     # Otherwise (non-Mac, not linking), copy the file contents and
#     150     # (optionally) copy the times and mode.
# --> 151     _copy_file_contents(src, dst)
#     152     if preserve_mode or preserve_times:
#     153         st = os.stat(src)
#
# /usr/lib/python3.6/distutils/file_util.py in _copy_file_contents(src, dst, buffer_size)
#      39
#      40         try:
# ---> 41             fdst = open(dst, 'wb')
#      42         except OSError as e:
#      43             raise DistutilsFileError(
#
# KeyboardInterrupt:

# %% [markdown]
# # The Below parts are for backup and don't need to be use, also maybe  some of the blow codes don not working!

# %%
# !ls /content/gdrive/My Drive/yolo_car_database
# Out:
# ls: cannot access '/content/gdrive/My': No such file or directory
# ls: cannot access 'Drive/yolo_car_database': No such file or directory

# %%
import urllib.request
from bs4 import BeautifulSoup
 
textToSearch = 'python tutorials'
query = urllib.parse.quote(textToSearch)
url = "https://www.youtube.com/results?search_query=" + query
response = urllib.request.urlopen(url)
html = response.read()
soup = BeautifulSoup(html, 'html.parser')
for vid in soup.findAll(attrs={'class':'yt-uix-tile-link'}):
    if not vid['href'].startswith("https://googleads.g.doubleclick.net/"):
        print('https://www.youtube.com' + vid['href'])

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt
 
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt'  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch2000:" "Ford Festiva" >> ford_video_list.txt 
 
# !echo '*****End of test 1 ******'

# %% [markdown]
# # I understand **HTTP Error 429 error** made because:
#
#  **The google don't like  too many request form one IP Address.**
#
# So tried to add these tags(` --rm-cache-dir --force-ipv4 --verbose `) to `youtube-dl` command as you can see below ( based of these reffrences [1][2] [2][3] [3][4]):
#
#  [1]: https://github.com/spectrico/vehicle-recognition-api-yolov4-python/blob/master/labels-makes.txt
#   [2]: https://askubuntu.com/questions/1220266/youtube-dl-do-not-working-http-error-429-too-many-requests-how-can-i-solve-this
#   [3]: https://forum.manjaro.org/t/youtube-dl-error-429-too-many-request/27150
#   [4]: https://stackoverflow.com/questions/59625386/how-could-we-solve-the-http-request-error-error-429-too-many-requests
#
# > Indented block

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt
 
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt' --rm-cache-dir --force-ipv4 --verbose  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch10:Ford Festiva"# >> ford_video_list.txt 
 
# !echo '*****End of test 1 ******'
# Out:
# Requirement already satisfied: youtube-dl in /usr/local/lib/python3.6/dist-packages (2020.11.12)
# [debug] System config: []
# [debug] User config: []
# [debug] Custom config: []
# [debug] Command-line args: ['--match-title', 'ford', '--add-metadata', '--write-thumbnail', '--list-thumbnails', '--mark-watched', '--write-info-json', 'ford_video_description_json.txt', '--write-description', 'ford_video_description.txt', '--rm-cache-dir', '--force-ipv4', '--verbose', '--cookies=Search-youtube-url-file.txt', '--ignore-errors', '--skip-download', '--get-url', '-f', 'bestvideo+bestaudio/best', '--default-search', 'ytsearch10:Ford Festiva#']
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2020.11.12
# [debug] Python version 3.6.9 (CPython) - Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# [debug] exe versions: ffmpeg 3.4.8, ffprobe 3.4.8
# [debug] Proxy map: {}
# *****End of test 1 ******

# %%
 
# !pip install youtube-search-python
from youtubesearchpython import SearchVideos
 
search = SearchVideos("NoCopyrightSounds", offset = 1, mode = "json", max_results = 20)
 
print(search.result())

# %%
# !youtube-dl "ytsearch1:how to create android app in app studio"
# Out:
# [download] Downloading playlist: how to create android app in app studio
# [youtube:search] query "how to create android app in app studio": Downloading page 1
# [youtube:search] playlist how to create android app in app studio: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] EOfCEhWq8sg: Downloading webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: How to Make an Android App for Beginners-EOfCEhWq8sg.f399.mp4
# [download]  93.2% of 72.94MiB at 27.48MiB/s ETA 00:00
# ERROR: Interrupted by user

# %%
# !pip install youtube-dl 
# !youtube-dl --default-search gvsearch5:how to develop for android --no-playlist --write-info-json --write-annotation --write-thumbnail --write-sub --skip-download 
# !youtube-dl --match-title 'ford' "ytsearch50":"Ford Festiva"+"peugeot 405"  --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4'
# Out:
# Requirement already satisfied: youtube-dl in /usr/local/lib/python3.6/dist-packages (2020.11.12)
# [download] Downloading playlist: Ford Festiva
# [youtube:search] query "Ford Festiva": Downloading page 1
# [youtube:search] query "Ford Festiva": Downloading page 2
# [youtube:search] query "Ford Festiva": Downloading page 3
# [youtube:search] playlist Ford Festiva: Downloading 50 videos
# [download] Downloading video 1 of 50
# [youtube] xFLckB7vOQc: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube] xFLckB7vOQc: Downloading MPD manifest
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.info.json
# [youtube] xFLckB7vOQc: Downloading thumbnail ...
# [youtube] xFLckB7vOQc: Writing thumbnail to: The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.webp
# [download] The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.mp4 has already been downloaded and merged
# [download] Downloading video 2 of 50
# [youtube] CfMFtXu3Lz4: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.info.json
# [youtube] CfMFtXu3Lz4: Downloading thumbnail ...
# [youtube] CfMFtXu3Lz4: Writing thumbnail to: 1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.webp
# [download] 1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.mp4 has already been downloaded and merged
# [download] Downloading video 3 of 50
# [youtube] xGTnAYr9jqM: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.info.json
# [youtube] xGTnAYr9jqM: Downloading thumbnail ...
# [youtube] xGTnAYr9jqM: Writing thumbnail to: ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.jpg
# [download] ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.mp4 has already been downloaded and merged
# [download] Downloading video 4 of 50
# [youtube] D50oPqdGIcw: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva Review-D50oPqdGIcw.info.json
# [youtube] D50oPqdGIcw: Downloading thumbnail ...
# [youtube] D50oPqdGIcw: Writing thumbnail to: 1991 Ford Festiva Review-D50oPqdGIcw.webp
# [download] 1991 Ford Festiva Review-D50oPqdGIcw.mp4 has already been downloaded and merged
# [download] Downloading video 5 of 50
# [youtube] I4tYuUmnjtY: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Driving a Modded Ford Festiva-I4tYuUmnjtY.info.json
# [youtube] I4tYuUmnjtY: Downloading thumbnail ...
# [youtube] I4tYuUmnjtY: Writing thumbnail to: Driving a Modded Ford Festiva-I4tYuUmnjtY.webp
# [download] Driving a Modded Ford Festiva-I4tYuUmnjtY.mp4 has already been downloaded and merged
# [download] Downloading video 6 of 50
# [youtube] 3XR9SoQU16c: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1989 Ford Shogun - Jay Leno's Garage-3XR9SoQU16c.info.json
# [youtube] 3XR9SoQU16c: Downloading thumbnail ...
# [youtube] 3XR9SoQU16c: Writing thumbnail to: 1989 Ford Shogun - Jay Leno's Garage-3XR9SoQU16c.webp
# [download] 1989 Ford Shogun - Jay Leno's Garage-3XR9SoQU16c.mp4 has already been downloaded and merged
# [download] Downloading video 7 of 50
# [youtube] CFLthXSQlbU: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Worlds First Turbo LS Ford Festiva in 6 Minutes-CFLthXSQlbU.info.json
# [youtube] CFLthXSQlbU: Downloading thumbnail ...
# [youtube] CFLthXSQlbU: Writing thumbnail to: Worlds First Turbo LS Ford Festiva in 6 Minutes-CFLthXSQlbU.jpg
# [download] Worlds First Turbo LS Ford Festiva in 6 Minutes-CFLthXSQlbU.mp4 has already been downloaded and merged
# [download] Downloading video 8 of 50
# [youtube] LBQ35YtdVf8: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube
# [download] Destination: 1991 Ford Festiva Manual 5-Speed Transmission - Bad Shaft-N37hSwjvGyo.f140.m4a
# [download] 100% of 1.34MiB in 00:00
# [ffmpeg] Merging formats into "1991 Ford Festiva Manual 5-Speed Transmission - Bad Shaft-N37hSwjvGyo.mp4"
# Deleting original file 1991 Ford Festiva Manual 5-Speed Transmission - Bad Shaft-N37hSwjvGyo.f135.mp4 (pass -k to keep)
# Deleting original file 1991 Ford Festiva Manual 5-Speed Transmission - Bad Shaft-N37hSwjvGyo.f140.m4a (pass -k to keep)
# [download] Downloading video 36 of 50
# [youtube] 36sAXUCzMjU: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Ford Festiva Camber Spacer Installation-36sAXUCzMjU.info.json
# [youtube] 36sAXUCzMjU: Downloading thumbnail ...
# [youtube] 36sAXUCzMjU: Writing thumbnail to: Ford Festiva Camber Spacer Installation-36sAXUCzMjU.webp
# [download] Ford Festiva Camber Spacer Installation-36sAXUCzMjU.mp4 has already been downloaded and merged
# [download] Downloading video 37 of 50
# [youtube] 8y8kVF9A_R4: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.info.json
# [youtube] 8y8kVF9A_R4: Downloading thumbnail ...
# [youtube] 8y8kVF9A_R4: Writing thumbnail to: 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.jpg
# [download] 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.mp4 has already been downloaded and merged
# [download] Downloading video 38 of 50
# [download] "Festiva Fuel Pump Relay and Wiring" title did not match pattern "ford"
# [download] Downloading video 39 of 50
# [youtube] 7xaD45cVVeQ: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.info.json
# [youtube] 7xaD45cVVeQ: Downloading thumbnail ...
# [youtube] 7xaD45cVVeQ: Writing thumbnail to: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.jpg
# [download] Destination: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f135.mp4
# [download] 100% of 6.77MiB in 00:00
# [download] Destination: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f140.m4a
# [download] 100% of 846.30KiB in 00:00
# [ffmpeg] Merging formats into "ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.mp4"
# Deleting original file ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f135.mp4 (pass -k to keep)
# Deleting original file ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f140.m4a (pass -k to keep)
# [download] Downloading video 40 of 50
# [youtube] 16LzO4ECzIE: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube] 16LzO4ECzIE: Downloading MPD manifest
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.info.json
# [youtube] 16LzO4ECzIE: Downloading thumbnail ...
# [youtube] 16LzO4ECzIE: Writing thumbnail to: 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.jpg
# [download] 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.mp4 has already been downloaded and merged
# [download] Downloading video 41 of 50
# [youtube] _tNbfZkBemE: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to:
Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Liam's In-Depths #14 - 1999 Ford Festiva GLXi Demon-AY6_82ETnCU.info.json
# [youtube] AY6_82ETnCU: Downloading thumbnail ...
# WARNING: Unable to download thumbnail "https://i.ytimg.com/vi_webp/AY6_82ETnCU/maxresdefault.webp": HTTP Error 404: Not Found
# [download] Liam's In-Depths #14 - 1999 Ford Festiva GLXi Demon-AY6_82ETnCU.mp4 has already been downloaded and merged
# [download] Downloading video 50 of 50
# [youtube] Fqrqqb3H43U: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube] Fqrqqb3H43U: Downloading MPD manifest
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.info.json
# [youtube] Fqrqqb3H43U: Downloading thumbnail ...
# [youtube] Fqrqqb3H43U: Writing thumbnail to: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.jpg
# [dashsegments] Total fragments: 16
# [download] Destination: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f135.mp4
# [download] 100% of 7.32MiB in 00:08
# [dashsegments] Total fragments: 9
# [download] Destination: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f140.m4a
# [download] 100% of 937.12KiB in 00:04
# [ffmpeg] Merging formats into "Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.mp4"
# Deleting original file Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f135.mp4 (pass -k to keep)
# Deleting original file Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f140.m4a (pass -k to keep)
# [download] Finished downloading playlist: Ford Festiva

# %%
# !pip install youtube-dl 
# %cd '/content/'

import os
try:
    os.remove('/content/yolo_car_database')
except OSError:
    pass

# !rm -rf '/content/yolo_car_database'
# !mkdir '/content/yolo_car_database'
# %cd '/content/yolo_car_database'
# !echo 't' >> t.txt
# !pwd 
# !ls
# !youtube-dl --default-search gvsearch5:how to develop for android --no-playlist --write-info-json --write-annotation --write-thumbnail --write-sub --skip-download 
# !youtube-dl --match-title 'ford ' "ytsearch50":"Ford Festiva"+"peugeot 405"  --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4'

# !rm -rf "/content/gdrive/My Drive/yolo_car_databe" && mkdir "/content/gdrive/My Drive/yolo_car_databe"

# !cp -r '/content/yolo_car_database' "/content/gdrive/My Drive/"

# %%
# !ls '/content/yolo_car_database2'

# %%
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails  --rm-cache-dir --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best  --default-search "ytsearch10:Ford Festiva"# >> ford_video_list.txt

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt

# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt'  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch50:" "Ford Festiva" >> ford_video_list.txt 

# !echo '*****End of test 1 ******'
