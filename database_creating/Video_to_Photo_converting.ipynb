# %%
#@title
# @markdown <center><h3>Input Your Mega ID</h3></center><br>
from functools import wraps
import errno
import os
import signal
import subprocess
import shlex


class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


if not os.path.exists("/root/.ipython/ocr.py"):
    from subprocess import run
    from shlex import split

    shellCmd = "wget -qq https://raw.githubusercontent.com/biplobsd/OneClickRun/master/res/ocr.py \
                    -O /root/.ipython/ocr.py"
    run(split(shellCmd))
from ocr import runSh

@timeout(10)
def runShT(args):
    return runSh(args, output=True)


# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
else:
    # !pkill mega-cmd

# INPUT YOUR MEGA ID

USERNAME = 'kayeyoc231@llubed.com'  # @param {type:"string"}
PASSWORD = "ss123456"  # @param {type:"string"}
if not (USERNAME == "" or PASSWORD == ""):
    try:
        runShT(f"mega-login {USERNAME} {PASSWORD}")
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")
# @markdown *After signing in, use the above cell(Main Cell) to transfer files from Mega to GDrive using the transfer quota of your Mega Pro Account*
# Out:
# Installing MEGA ...
# Selecting previously unselected package megacmd.
# (Reading database ... 144829 files and directories currently installed.)
# Preparing to unpack .../cache/apt/archives/MEGAcmd.deb ...
# Unpacking megacmd (1.4.0-3.1) ...
# Setting up megacmd (1.4.0-3.1) ...
# MEGA is installed.
# [Initiating server in background. Log: /root/.megaCmd/megacmdserver.log]
# Account e-mail: kayeyoc231@llubed.com

# %% [markdown]
# # Download the Yolo dtabase form Mega.nz drive

# %%
import sys, os, urllib.request
import time
import subprocess
import contextlib
from IPython.display import clear_output
#@markdown <br><center><img src='https://mega.nz/favicon.ico?v=3' height="50" alt="MEGA-logo"/></center>
#@markdown <center><h2>Transfer from Mega to GDrive</h2></center><br>
HOME = os.path.expanduser("~")
if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/biplobsd/" \
                "OneClickRun/master/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import (
    runSh,
    loadingAn,
)
#@title MEGA public link download
URL = "https://mega.nz/folder/xEljCCgD#KAq3WTA897PFhXWlaR1s6g" #@param {type:"string"}
OUTPUT_PATH = "" #@param {type:"string"}
if not OUTPUT_PATH:
  os.makedirs("downloads", exist_ok=True)
  OUTPUT_PATH = "downloads"
# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    loadingAn()
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
    clear_output()

# Unix, Windows and old Macintosh end-of-line
newlines = ['\n', '\r\n', '\r']

def unbuffered(proc, stream='stdout'):
    stream = getattr(proc, stream)
    with contextlib.closing(stream):
        while True:
            out = []
            last = stream.read(1)
            # Don't loop forever
            if last == '' and proc.poll() is not None:
                break
            while last not in newlines:
                # Don't loop forever
                if last == '' and proc.poll() is not None:
                    break
                out.append(last)
                last = stream.read(1)
            out = ''.join(out)
            yield out


def transfare():
    import codecs
    decoder = codecs.getincrementaldecoder("UTF-8")()
    cmd = ["mega-get", URL, OUTPUT_PATH]
    proc = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        # Make all end-of-lines '\n'
        universal_newlines=True,
    )
    for line in unbuffered(proc):
        print(line)
        


transfare()
# Out:
# TRANSFERRING ||............................................||(0/0 KB:   0.00 %)
# TRANSFERRING ||########################################||(265/265 MB: 100.00 %)
# Download finished: /content/downloads/Yolo_car_database
# TRANSFERRING ||######################################||(2313/2313 MB: 100.00 %)

# %% [markdown]
# # Convering Every video to some phot in folders

# %%
from ocr import runSh
runShTS('mega-cd /')
runShTS('mega-mkdir Yolo_car_database_photos')
runShTS('mega-cd Yolo_car_database_photos')

def change_Video_name(name):
    name_file = ''.join(name)
    name_file = name_file.replace(".mp4", "_")
    
    return name_file
import os

def runShTS(args):
    return runSh(args, output=True)
def convert_to_photo(root, Video_name):
  runShTS('mkdir '+Video_name)
  print (Video_name+'\n')
  print ('ffmge vomand is :'+'ffmpeg -i '+root+' -vf fps=1 '+Video_name+'out%d.png\n')
  runShTS('ffmpeg -i '+root+' -vf fps=1 '+Video_name+'out%d.png')
def Upload_phtos_to_mega(root,mkdir_name):
  runShTS('mega-cd /Yolo_car_database_photos')
  runShTS('mega-mkdir '+mkdir_name)
  runShTS('mega-cd '+mkdir_name)
  runShTS('mega-put '+root+ ' .')
  # for path, subdirs, files in os.walk( Yolo_video_path):
  #     for name in subdirs:
  
  #       runShTS('mega-cd Yolo_car_database_photos' + title1 + '/')
  #       runShTS('mega-put '+ root+' . ')
  #       runShTS(' mega-ls')

Yolo_video_path='/content/downloads/Yolo_car_database/'
Yolo_photo_path='/content/downloads/Yolo_car_database_photo/'
runShTS('rm -rf '+Yolo_photo_path)
runShTS('mkdir '+Yolo_photo_path)

for path, subdirs, files in os.walk( Yolo_video_path):
      for name in subdirs:
        #  convert_to_phot(Yolo_video_path)
        print (path+'/'+name+'\n')
        Vidoe_folder=path+'/'+name+'/'
        for path2, subdirs2, files2 in os.walk( path+'/'+name):
          for name2 in files2:
             print (path2+'/'+name2+'\n')
             if name2.endswith(".mp4"):
                convert_to_photo(path2+'/'+name2,Yolo_photo_path+change_Video_name(name2))

for path, subdirs, files in os.walk( Yolo_photo_path):
      for name in subdirs:
        #  convert_to_phot(Yolo_video_path)
        print ('Photo Path is :'+path+'/'+name+'\n')
        photo_folder=path+'/'+name+'/'
        Upload_phtos_to_mega(photo_folder,name)
# Out:
# [API:err: 01:24:55] Folder already exists: Yolo_car_database_photos
# /content/downloads/Yolo_car_database//ToyotaCamry
#
# /content/downloads/Yolo_car_database//ToyotaCamry/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA.webp
#
# /content/downloads/Yolo_car_database//ToyotaCamry/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg.info.json
#
# /content/downloads/Yolo_car_database//ToyotaCamry/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg.mp4
#
# /content/downloads/Yolo_car_database_photo/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//ToyotaCamry/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//ToyotaCamry/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:07:56.08, start: 0.000000, bitrate: 1590 kb/s
# Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1486 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn, 59.94 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  476 fps= 12 q=-0.0 Lsize=N/A time=00:07:56.00 bitrate=N/A speed=11.8x
# video:633714kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.mp4
#
# /content/downloads/Yolo_car_database_photo/2021_Camry_Overview___ToyotaHFOFnDet8ao_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/2021_Camry_Overview___ToyotaHFOFnDet8ao_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:07:39.78, start: 0.000000, bitrate: 1638 kb/s
# Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1538 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/2021_Camry_Overview___ToyotaHFOFnDet8ao_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  460 fps= 14 q=-0.0 Lsize=N/A time=00:07:40.00 bitrate=N/A speed=13.9x
# video:371931kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.info.json
#
# /content/downloads/Yolo_car_database//ToyotaCamry/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA.info.json
#
# /content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.en.vtt
#
# /content/downloads/Yolo_car_database//ToyotaCamry/Why_Not_to_Buy_a_New_Toyota_Camry65Id2686cVg.webp
#
# /content/downloads/Yolo_car_database//ToyotaCamry/2021_Camry_Overview___ToyotaHFOFnDet8ao.webp
#
# /content/downloads/Yolo_car_database//ToyotaCamry/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA.mp4
#
# /content/downloads/Yolo_car_database_photo/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//ToyotaCamry/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//ToyotaCamry/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:07:26.01, start: 0.000000, bitrate: 1815 kb/s
# Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1711 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/2020_Toyota_Camry___Review_&__Road_TestmGM9rULtJdA_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  446 fps= 12 q=-0.0 Lsize=N/A time=00:07:26.00 bitrate=N/A speed=12.1x
# video:403364kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//BMW5_Series
#
# /content/downloads/Yolo_car_database//BMW5_Series/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM.info.json
#
# /content/downloads/Yolo_car_database//BMW5_Series/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM.jpg
#
# /content/downloads/Yolo_car_database//BMW5_Series/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM.mp4
#
# /content/downloads/Yolo_car_database_photo/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//BMW5_Series/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//BMW5_Series/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:13:55.66, start: 0.000000, bitrate: 666 kb/s
# Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 564 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/Exploring_the_new_BMW_5_Series,_inside_and_out.Lh4xMqL7GXM_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  836 fps= 16 q=-0.0 Lsize=N/A time=00:13:56.00 bitrate=N/A speed=15.8x
# video:580930kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//Peugeot_405
#
# /content/downloads/Yolo_car_database//Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4
#
# /content/downloads/Yolo_car_database_photo/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:09:01.79, start: 0.000000, bitrate: 434 kb/s
# Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x356 [SAR 1:1 DAR 160:89], 331 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 640x356 [SAR 1:1 DAR 160:89], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  542 fps= 62 q=-0.0 Lsize=N/A time=00:09:02.00 bitrate=N/A speed=61.5x
# video:109850kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json
#
# /content/downloads/Yolo_car_database//Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg
#
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk.info.json
#
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk.webp
#
# /content/downloads/Yolo_car_database//Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg
#
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp
#
# /content/downloads/Yolo_car_database//Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json
#
# /content/downloads/Yolo_car_database//Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json
#
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4
#
# /content/downloads/Yolo_car_database_photo/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:07:29.52, start: 0.000000, bitrate: 2403 kb/s
# Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 2302 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  449 fps= 13 q=-0.0 Lsize=N/A time=00:07:29.00 bitrate=N/A speed=12.7x
# video:393905kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4
#
# /content/downloads/Yolo_car_database_photo/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:08:50.25, start: 0.000000, bitrate: 475 kb/s
# Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x356 [SAR 1:1 DAR 160:89], 372 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 640x356 [SAR 1:1 DAR 160:89], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  530 fps= 59 q=-0.0 Lsize=N/A time=00:08:50.00 bitrate=N/A speed=59.2x
# video:127030kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk.mp4
#
# /content/downloads/Yolo_car_database_photo/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//Peugeot_405/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:05:06.02, start: 0.000000, bitrate: 1407 kb/s
# Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1305 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/Peugeot_405_SRI__Walk_Around,_Start_Up,_and_DriveME0ZxEP93uk_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png
# frame=  306 fps= 15 q=-0.0 Lsize=N/A time=00:05:06.00 bitrate=N/A speed=15.2x
# video:258374kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content/downloads/Yolo_car_database//OpelAstra
#
# /content/downloads/Yolo_car_database//Porsche911
#
# /content/downloads/Yolo_car_database//Ford_Festiva
#
# /content/downloads/Yolo_car_database//Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4
#
# /content/downloads/Yolo_car_database_photo/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM_
#
# ffmge vomand is :ffmpeg -i /content/downloads/Yolo_car_database//Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4 -vf fps=1 /content/downloads/Yolo_car_database_photo/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM_out%d.png
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
# libavutil      55. 78.100 / 55. 78.100
# libavcodec     57.107.100 / 57.107.100
# libavformat    57. 83.100 / 57. 83.100
# libavdevice    57. 10.100 / 57. 10.100
# libavfilter     6.107.100 /  6.107.100
# libavresample   3.  7.  0 /  3.  7.  0
# libswscale      4.  8.100 /  4.  8.100
# libswresample   2.  9.100 /  2.  9.100
# libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/downloads/Yolo_car_database//Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Duration: 00:19:31.94, start: 0.000000, bitrate: 1903 kb/s
# Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1799 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
# Metadata:
# handler_name    : SoundHandler
# Stream mapping:
# Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/downloads/Yolo_car_database_photo/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM_out%d.png':
# Metadata:
# major_brand     : isom
# minor_version   : 512
# compatible_brands: isomiso2avc1mp41
# encoder         : Lavf57.83.100
# Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
# Metadata:
# handler_name    : VideoHandler
# encoder         : Lavc57.107.100 png

# %%
# !sudo apt install tree
# !tree /content/downloads/Yolo_car_database_photo
