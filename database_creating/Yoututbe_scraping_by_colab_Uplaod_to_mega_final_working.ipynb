# %% [markdown]
# <a href="https://colab.research.google.com/github/CAR-Driving/yoloOnGoogleColab/blob/master/database_creating/Yoututbe_scraping_by_colab_Uplaod_to_mega_final_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The main function for scrapin the car type video from the **car_type_label.txt** file and download data by youtube-dl comand for each line of that txt file

# %% [markdown]
# # @title
# # conect to [Mega.z](https://mega.nz/) cloud for storage files based ot this page:
#
# https://colab.research.google.com/github/sudo-ken/Mega-to-Google-Drive/blob/master/Transfer_files_from_Mega_to_Google_Drive.ipynb#scrollTo=Vgh1xlQYGZCO

# %%
#@title
# @markdown <center><h3>Input Your Mega ID</h3></center><br>
from functools import wraps
import errno
import os
import signal
import subprocess
import shlex


class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


if not os.path.exists("/root/.ipython/ocr.py"):
    from subprocess import run
    from shlex import split

    shellCmd = "wget -qq https://raw.githubusercontent.com/biplobsd/OneClickRun/master/res/ocr.py \
                    -O /root/.ipython/ocr.py"
    run(split(shellCmd))
from ocr import runSh

@timeout(10)
def runShT(args):
    return runSh(args, output=True)


# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
else:
    # !pkill mega-cmd

# INPUT YOUR MEGA ID

USERNAME = 'kayeyoc231@llubed.com'  # @param {type:"string"}
PASSWORD = "ss123456"  # @param {type:"string"}
if not (USERNAME == "" or PASSWORD == ""):
    try:
        runShT(f"mega-login {USERNAME} {PASSWORD}")
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")
# @markdown *After signing in, use the above cell(Main Cell) to transfer files from Mega to GDrive using the transfer quota of your Mega Pro Account*
# Out:
# [Initiating server in background. Log: /root/.megaCmd/megacmdserver.log]
# Resuming session ...
# [API:err: 23:05:48] Already logged in. Please log out first.
# Account e-mail: kayeyoc231@llubed.com

# %%
# !pip install youtube-dl 
# !apt install python3-distutils   
# !pip install mega.py
# !apt install python3-distutils  -y

# %cd '/content/'
# !git clone https://github.com/jeroenmeulenaar/python3-mega.git
# !(cd python3-mega; pip install urlobject pycrypto)

# import os
# os.chdir('python3-mega')
# from mega import Mega
# os.chdir('../')
# m = Mega.from_ephemeral()

# !git clone https://github.com/odwyersoftware/mega.py
# %cd mega.py
# !python setup.py install
# %cd '/content/'

# !rm -rf '/content/yoloOnGoogleColab'
# !git clone https://github.com/CAR-Driving/yoloOnGoogleColab
# Out:
# Collecting youtube-dl
#   Downloading https://files.pythonhosted.org/packages/69/5a/efd35e71b65974f3e559c3d5afc18166e9de91a1da1a10620f8c515e0ae9/youtube_dl-2020.11.24-py2.py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 5.2MB/s
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2020.11.24
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-distutils is already the newest version (3.6.9-1~18.04).
# python3-distutils set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Collecting mega.py
#   Downloading https://files.pythonhosted.org/packages/a3/51/44a1085a091c27ade09e122d5abdafb4b6400265081879a7c4e32973a175/mega.py-1.0.8-py2.py3-none-any.whl
# Collecting pycryptodome<4.0.0,>=3.9.6
#   Downloading https://files.pythonhosted.org/packages/2b/6f/7e38d7c97fbbc3987539c804282c33f56b6b07381bf2390deead696440c5/pycryptodome-3.9.9-cp36-cp36m-manylinux1_x86_64.whl (13.7MB)
#      |████████████████████████████████| 13.7MB 290kB/s
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from mega.py) (1.0.1)
# Collecting tenacity<6.0.0,>=5.1.5
#   Downloading https://files.pythonhosted.org/packages/45/67/67bb1db087678bc5c6f20766cf18914dfe37b0b9d4e4c5bb87408460b75f/tenacity-5.1.5-py2.py3-none-any.whl
# Requirement already satisfied: requests>=0.10 in /usr/local/lib/python3.6/dist-packages (from mega.py) (2.23.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tenacity<6.0.0,>=5.1.5->mega.py) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (2020.11.8)
# Installing collected packages: pycryptodome, tenacity, mega.py
# Successfully installed mega.py-1.0.8 pycryptodome-3.9.9 tenacity-5.1.5
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-distutils is already the newest version (3.6.9-1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# /content
# Cloning into 'yoloOnGoogleColab'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 264 (delta 0), reused 0 (delta 0), pack-reused 260
# Receiving objects: 100% (264/264), 43.38 MiB | 31.17 MiB/s, done.
# Resolving deltas: 100% (148/148), done.

# %%
# !rm -rf '/content/yolo_car_database'
# !mkdir '/content/yolo_car_database'
# %cd '/content/yolo_car_database'
# !echo 't' >> t.txt

from subprocess import Popen, PIPE
import shlex
import errno, os

from subprocess import Popen, PIPE
import shlex
from ocr import runSh
import re
from distutils.dir_util import copy_tree

# copy subdirectory example
fromDirectory = '/content/yolo_car_database/'
toDirectory = '/content/gdrive/My Drive/yolo_car_database/'

runSh('mega-cd /' )
runSh(' mega-mkdir Yolo_car_database ')
runSh(' mega-ls ')
runSh('mega-cd Yolo_car_database ')

# copy_tree(fromDirectory, toDirectory)
def uplaod_mega_nz(root,cloude='google_drive',title1=''):
 if (cloude=='mega'):
  #  from mega import Mega
  #  mega = Mega()
  #  email = 'woraqofa@ivyandmarj.com'
  #  password = 'feripas800@wgraj.com'
  #  m = mega.login(email, password)
  #  # login using a temporary anonymous account
  #  m = mega.login()
  #  quota = m.get_quota()
  #  # specify unit output kilo, mega, gig, else bytes will output
  #  space = m.get_storage_space(kilo=True)
  #  m.create_folder('yolo_car_database/'+title1+'/')
  #  folder = m.find('yolo_car_database/'+title1+'/')
   # m.upload('myfile.doc', folder[0])
  #  run_command('mega-cd ~ && mega-mkdir Yolo_car_database && mega-cd Yolo_car_database && mega-put '+ root+'/* . ')
  
   runSh('mega-cd Yolo_car_database' + title1 + '/')
   runSh('mega-put '+ root+' . ')
   runSh(' mega-ls')

   for path, subdirs, files in os.walk( root):
      for name in files:
        print (files)
          # m.upload(os.path.join(path, name), folder[0])
   # public_exported_web_link = m.export('myfile.doc')
   # public_exported_web_link = m.export('my_mega_folder/my_sub_folder_to_share')
 if (cloude=='google_drive'):
     run_command('mkdir '+root+'/')
     for path, subdirs, files in os.walk( root):
      for name in files:
        # print ('cp -r "'+os.path.join(path, name)+'" '+'"/content/gdrive/My Drive/yolo_car_database/' + title1 + '/"')
        # print (os.path.join(path, change_name(name)))       
        # os.rename(os.path.join(path, name), os.path.join(path, change_name(name)))
        run_command('cp -r  "'+os.path.join(path, name)+'" '+'"/content/gdrive/My Drive/yolo_car_database/' + title1 + '/"')
     try:
        copy_tree(root,'/content/gdrive/My Drive/yolo_car_database/' + title1 + '/')
     except OSError as e: # this would be "except OSError, e:" before Python 2.6
        if e.errno != errno.ENOENT: # errno.ENOENT = no such file or directory
            # raise #
            i=0   
def change_file_name(root):
  for path, subdirs, files in os.walk( root):
      for name in files:
        print ('filename is: "'+os.path.join(path, name))
        print (os.path.join(path, change_name(name)))       
        os.rename(os.path.join(path, name), os.path.join(path, change_name(name)))

def run_command(cmd):
    with Popen(shlex.split(cmd), stdout=PIPE, bufsize=1, universal_newlines=False) as p:
        while True:
            line = p.stdout.readline()
            if not line:
                break
            print(line)    
        exit_code = p.poll()
    return exit_code
def change_name(name):
    name_file = ''.join(name)
    name_file = name_file.replace(" ", "_")
    name_file = name_file.replace("'", "_")
    name_file = name_file.replace("\n", "")
    name_file = name_file.replace("\t", "")
    name_file = name_file.replace("!", "")
    name_file = name_file.replace("-", "")
    name_file = name_file.replace("$", "")
    name_file = re.sub(r'[\\/*?:"<>|]',"",name_file)
    return name_file
def Youtube_download_video(command):
    # command_title=re.split('([^a-zA-Z0-9])',command)
    command_title_1 = re.split('([^a-zA-Z0-9])', command)
    command_title = ''.join(command_title_1)
    command_title=change_name(command_title)


    # call_args = ' youtube-dl --match-title ' + ' "'+command_title_1[0]+ '" ' + '"ytsearch10":'+'"'+command+ '" '+"--external-downloader-args   '-ss 00:00:03 -t 00:03:08' --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4'"
    call_args = ' youtube-dl --match-title ' + ' "'+command_title_1[0]+ '" ' + '"ytsearch100":'+'"'+command+ '" '+"--playlist-end 3  --external-downloader-args   '-ss 00:00:03 -t 00:03:08' --write-info-json --write-annotation --write-thumbnail --write-sub -f 'best[ext=mp4,height<=1080]+best[filesize<100M]' "

    # call_args = call_args.split() # because call takes a list of strings
    # print (call_args)
    # call(call_args)
    # os.chdir("/content/yolo_car_database")
    # run_command('cd "/content/yolo_car_database"') 
    # run_command(call_args)
    # os.system("cp --recursive '/content/yolo_car_database' '/content/gdrive/My Drive/yolo_car_databe")
    # os.system('pwd && ls ')
    # copy_tree(fromDirectory, toDirectory)
    # p = Popen(shlex.split(call_args), bufsize=1, universal_newlines=True)
    run_command('mkdir /content/yolo_car_database/'+command_title)
    
    os.chdir( '/content/yolo_car_database/'+command_title+'/')
    run_command(call_args) 
    # copy_tree('/content/yolo_car_database/'+command_title+'/', '/content/gdrive/My Drive/yolo_car_database/'+command_title+'/')
    change_file_name('/content/yolo_car_database/'+command_title+'/')
    uplaod_mega_nz('/content/yolo_car_database/'+command_title+'/','mega',command_title)
    try:
        # call(call_args)
        # run_command('mkdir /content/yolo_car_database/'+command_title)
        # os.chdir( '/content/yolo_car_database/'+command_title+'/')
        # run_command(call_args) 
        # copy_tree('/content/yolo_car_database/'+command_title+'/', toDirectory)

        # print (call_args)
        pp=0
        
    except OSError as e: # this would be "except OSError, e:" before Python 2.6
        if e.errno != errno.ENOENT: # errno.ENOENT = no such file or directory
            raise # re-raise exception if a different error occurred
 
    # return p.poll()

# !wget https://github.com/spectrico/car-make-model-classifier-yolo3-python/blob/master/labels.txt

i=0
for line in open('/content/yoloOnGoogleColab/car_type_label.txt','r').readlines():
    print (line)
    try:
      Youtube_download_video(line)

    except OSError as e: # this would be "except OSError, e:" before Python 2.6
        if e.errno != errno.ENOENT: # errno.ENOENT = no such file or directory
            i=1 # re-raise exception if a different error occurred
    i=i+1
# !cp '/content/yolo_car_database' "gdrive/My Drive/yolo_car_databe"
# Out:
# /content/yolo_car_database
# Ford Festiva
#
# b'[download] Downloading playlist: Ford Festiva\n'
# b'[youtube:search] query "Ford Festiva": Downloading page 1\n'
# b'[youtube:search] playlist Ford Festiva: Downloading 3 videos\n'
# b'[download] Downloading video 1 of 3\n'
# b'[youtube] xFLckB7vOQc: Downloading webpage\n'
# b'[youtube] xFLckB7vOQc: Downloading MPD manifest\n'
# b'[info] Writing video description metadata as JSON to: The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.info.json\n'
# b'[youtube] xFLckB7vOQc: Downloading thumbnail ...\n'
# b'[youtube] xFLckB7vOQc: Writing thumbnail to: The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.webp\n'
# b'[download] Destination: The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.f22.mp4\n'
# b'\r[download]   0.0% of 173.08MiB at Unknown speed ETA Unknown ETA\r[download]   0.0% of 173.08MiB at Unknown speed ETA Unknown ETA\r[download]   0.0% of 173.08MiB at Unknown speed ETA Unknown ETA\r[download]   0.0% of 173.08MiB at  1.27MiB/s ETA 02:16\r[download]   0.0% of 173.08MiB at  1.96MiB/s ETA 01:28\r[download]   0.0% of 173.08MiB at  2.44MiB/s ETA 01:10\r[download]   0.1% of 173.08MiB at  3.65MiB/s ETA 00:47\r[download]   0.1% of 173.08MiB at  5.45MiB/s ETA 00:31\r[download]   0.3% of 173.08MiB at  8.81MiB/s ETA 00:19\r[download]   0.6% of 173.08MiB at 14.66MiB/s ETA 00:11\r[download]   1.2% of 173.08MiB at 25.12MiB/s ETA 00:06\r[download]   2.3% of 173.08MiB at 34.59MiB/s ETA 00:04\r[download]   4.6% of 173.08MiB at 40.74MiB/s ETA 00:04\r[download]   6.9% of 173.08MiB at 48.53M
991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.f18.mp4 (pass -k to keep)\n'
# b'[download] Finished downloading playlist: Ford Festiva\n'
# filename is: "/content/yolo_car_database/Ford_Festiva/ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.info.json
# /content/yolo_car_database/Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json
# filename is: "/content/yolo_car_database/Ford_Festiva/1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.mp4
# /content/yolo_car_database/Ford_Festiva/1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4
# filename is: "/content/yolo_car_database/Ford_Festiva/ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.mp4
# /content/yolo_car_database/Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4
# filename is: "/content/yolo_car_database/Ford_Festiva/1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.info.json
# /content/yolo_car_database/Ford_Festiva/1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json
# filename is: "/content/yolo_car_database/Ford_Festiva/ROAD TRIPPING a $300 FORD FESTIVA!-xGTnAYr9jqM.jpg
# /content/yolo_car_database/Ford_Festiva/ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg
# filename is: "/content/yolo_car_database/Ford_Festiva/The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.webp
# /content/yolo_car_database/Ford_Festiva/The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp
# filename is: "/content/yolo_car_database/Ford_Festiva/The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.info.json
# /content/yolo_car_database/Ford_Festiva/The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json
# filename is: "/content/yolo_car_database/Ford_Festiva/The 1989 Ford Festiva is a 50mpg Classic Hatchback-xFLckB7vOQc.mp4
# /content/yolo_car_database/Ford_Festiva/The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4
# filename is: "/content/yolo_car_database/Ford_Festiva/1991 Ford Festiva - Regular Car Reviews-CfMFtXu3Lz4.webp
# /content/yolo_car_database/Ford_Festiva/1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# ['ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.mp4', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.webp', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.mp4', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.jpg', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.mp4', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.info.json', 'The_1989_Ford_Festiva_is_a_50mpg_Classic_HatchbackxFLckB7vOQc.webp', 'ROAD_TRIPPING_a_300_FORD_FESTIVAxGTnAYr9jqM.info.json', '1991_Ford_Festiva__Regular_Car_ReviewsCfMFtXu3Lz4.info.json']
# Peugeot 405
#
# b'[download] Downloading playlist: Peugeot 405\n'
# b'[youtube:search] query "Peugeot 405": Downloading page 1\n'
# b'[youtube:search] playlist Peugeot 405: Downloading 3 videos\n'
# b'[download] Downloading video 1 of 3\n'
# b'[youtube] LG9gyi9X23A: Downloading webpage\n'
# b'[youtube] LG9gyi9X23A: Downloading MPD manifest\n'
# b'[info] Writing video description metadata as JSON to: 1988 Peugeot 405 mi16 Motorweek review-LG9gyi9X23A.info.json\n'
# b'[youtube] LG9gyi9X23A: Downloading thumbnail ...\n'
# b'[youtube] LG9gyi9X23A: Writing thumbnail to: 1988 Peugeot 405 mi16 Motorweek review-LG9gyi9X23A.jpg\n'
B/s ETA 00:10\r[download]   2.6% of 37.79MiB at  5.77MiB/s ETA 00:06\r[download]   5.3% of 37.79MiB at  9.95MiB/s ETA 00:03\r[download]  10.6% of 37.79MiB at  7.48MiB/s ETA 00:04\r[download]  21.2% of 37.79MiB at  6.36MiB/s ETA 00:04\r[download]  31.8% of 37.79MiB at  5.76MiB/s ETA 00:04\r[download]  42.3% of 37.79MiB at  5.90MiB/s ETA 00:03\r[download]  52.9% of 37.79MiB at  5.55MiB/s ETA 00:03\r[download]  63.5% of 37.79MiB at  5.62MiB/s ETA 00:02\r[download]  74.1% of 37.79MiB at  5.32MiB/s ETA 00:01\r[download]  84.7% of 37.79MiB at  5.46MiB/s ETA 00:01\r[download]  95.3% of 37.79MiB at  5.47MiB/s ETA 00:00\r[download] 100.0% of 37.79MiB at  5.31MiB/s ETA 00:00\r[download] 100% of 37.79MiB in 00:07\n'
# b'[ffmpeg] Merging formats into "Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.mp4"\n'
# b'Deleting original file Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.f22.mp4 (pass -k to keep)\n'
# b'Deleting original file Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.f18.mp4 (pass -k to keep)\n'
# b'[download] Finished downloading playlist: Peugeot 405\n'
# filename is: "/content/yolo_car_database/Peugeot_405/1990 Peugeot 405 Wagon Motorweek review-jVm5rfk4H48.mp4
# /content/yolo_car_database/Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4
# filename is: "/content/yolo_car_database/Peugeot_405/1990 Peugeot 405 Wagon Motorweek review-jVm5rfk4H48.jpg
# /content/yolo_car_database/Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg
# filename is: "/content/yolo_car_database/Peugeot_405/Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.webp
# /content/yolo_car_database/Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp
# filename is: "/content/yolo_car_database/Peugeot_405/Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.info.json
# /content/yolo_car_database/Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json
# filename is: "/content/yolo_car_database/Peugeot_405/1988 Peugeot 405 mi16 Motorweek review-LG9gyi9X23A.mp4
# /content/yolo_car_database/Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4
# filename is: "/content/yolo_car_database/Peugeot_405/Peugeot 405 Rescue - Part 1-HPMXJYtnxnQ.mp4
# /content/yolo_car_database/Peugeot_405/Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4
# filename is: "/content/yolo_car_database/Peugeot_405/1988 Peugeot 405 mi16 Motorweek review-LG9gyi9X23A.jpg
# /content/yolo_car_database/Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg
# filename is: "/content/yolo_car_database/Peugeot_405/1990 Peugeot 405 Wagon Motorweek review-jVm5rfk4H48.info.json
# /content/yolo_car_database/Peugeot_405/1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json
# filename is: "/content/yolo_car_database/Peugeot_405/1988 Peugeot 405 mi16 Motorweek review-LG9gyi9X23A.info.json
# /content/yolo_car_database/Peugeot_405/1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# ['1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.mp4', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.info.json', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.jpg', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.jpg', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.webp', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.info.json', '1988_Peugeot_405_mi16_Motorweek_reviewLG9gyi9X23A.info.json', 'Peugeot_405_Rescue__Part_1HPMXJYtnxnQ.mp4', '1990_Peugeot_405_Wagon_Motorweek_reviewjVm5rfk4H48.mp4']
# Toyota	Corolla
#
# b'[download] Downloading playlist: Toyota\tCorolla\n'
# b'[youtube:search] query "Toyota\tCorolla": Downloading page 1\n'
# b'[youtube:search] playlist Toyota\tCorolla: Downloading 3 videos\n'
# b'[download] Downloading video 1 of 3\n'
# b'[youtube] G6LigiflRzw: Downloading webpage\n'
# b'[info] Writing video description metadata as JSON to: 2020 Toyota Corolla - Review & Road Test-G6LigiflRzw.info.json\n'
# b'[youtube] G6LigiflRzw: Downloading thumbnail ...\n'
# b'[youtube] G6LigiflRzw: Writing thumbnail to: 2020 Toyota Corolla - Review & Road Test-G6LigiflRzw.webp\n'
# b'[download] Destination: 2020 Toyota Corolla - Review & Road Test-G6LigiflRzw.f22.mp4\n'
# b'\r[download]   0.0% of 54.53MiB at Unknown speed ETA Unknown ETA\r[download]   0.0% of 54.53MiB at Unknown speed ETA Unknown ETA\r[download]   0.0% of 54.53MiB at 693.16KiB/s ETA 01:20\r[download]   0.0% of 54.53MiB at  1.41MiB/s ETA 00:38\r[download]   0.1% of 54.53MiB at  2.15MiB/s ETA 00:25\r[download]   0.1% of 54.53MiB at  2.56MiB/s ETA 00:21\r[download]   0.2% of 54.53MiB at  3.63MiB/s ETA 00:14\r[download]   0.5% of 54.53MiB at  2.68MiB/s ETA 00:20\r[download]   0.9% of 54.53MiB at  4.71MiB/s ETA 00:11\r[download]   1.8% of 54.53MiB at  8.40MiB/s ETA 00:06\r[download]   3.7% of 54.53MiB at 15.02MiB/s ETA 00:03\r[download]   7.3% of 54.53MiB at 26.34MiB/s ETA 00:01\r[download]  14.7% of 54.53MiB at 18.37MiB/s ETA 00:02\r[download]  22.0% of 54.53MiB at 21.52MiB/s ETA 00:01\r[download]  29.3% of 54.53MiB at 24.20MiB/s ETA 00:01\r[download]  36.7% of 54.53MiB at 25.54MiB/s ETA 00:01\r[download]  44.0% of 54.53MiB at 28.59MiB/s ETA 00:01\r[download]  51.3% of 54.53MiB at 29.34MiB/s ETA 00:00\r[download]  58.7% of 54.53MiB at 31.18MiB/s ETA 00:00\r[download]  66.0% of 54.53MiB at 29.71MiB/s ETA 00:00\r[download]  73.3% of 54.53MiB at 30.18MiB/s ETA 00:00\r[download]  80.7% of 54.53MiB at 31.88MiB/s ETA 00:00\r[download]  88.0% of 54.53MiB at 33.28MiB/s ETA 00:00\r[download]  95.4% of 54.53MiB at 32.58MiB/s ETA 00:00\r[download] 100.0% of 54.53MiB at 33.11MiB/s ETA 00:00\r[download] 100% of 54.53MiB in 00:01\n'
 73.13MiB at 71.96MiB/s ETA 00:00\r[download]  16.4% of 73.13MiB at 92.39MiB/s ETA 00:00\r[download]  21.9% of 73.13MiB at 105.93MiB/s ETA 00:00\r[download]  27.3% of 73.13MiB at 115.26MiB/s ETA 00:00\r[download]  32.8% of 73.13MiB at 118.17MiB/s ETA 00:00\r[download]  38.3% of 73.13MiB at 125.98MiB/s ETA 00:00\r[download]  43.8% of 73.13MiB at 129.60MiB/s ETA 00:00\r[download]  49.2% of 73.13MiB at 133.63MiB/s ETA 00:00\r[download]  54.7% of 73.13MiB at 134.51MiB/s ETA 00:00\r[download]  60.2% of 73.13MiB at 137.31MiB/s ETA 00:00\r[download]  65.6% of 73.13MiB at 137.12MiB/s ETA 00:00\r[download]  71.1% of 73.13MiB at 138.93MiB/s ETA 00:00\r[download]  76.6% of 73.13MiB at 141.00MiB/s ETA 00:00\r[download]  82.0% of 73.13MiB at 140.52MiB/s ETA 00:00\r[download]  87.5% of 73.13MiB at 137.83MiB/s ETA 00:00\r[download]  93.0% of 73.13MiB at 138.08MiB/s ETA 00:00\r[download]  98.5% of 73.13MiB at 139.42MiB/s ETA 00:00\r[download] 100.0% of 73.13MiB at 140.51MiB/s ETA 00:00\r[download] 100% of 73.13MiB in 00:00\n'
# b'[ffmpeg] Merging formats into "AWD Trophy Truck Pulls a Wheelie Vs Ken Block\xe2\x80\x99s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.mp4"\n'
# b'Deleting original file AWD Trophy Truck Pulls a Wheelie Vs Ken Block\xe2\x80\x99s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.f22.mp4 (pass -k to keep)\n'
# b'Deleting original file AWD Trophy Truck Pulls a Wheelie Vs Ken Block\xe2\x80\x99s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.f18.mp4 (pass -k to keep)\n'
# b'[download] Finished downloading playlist: Ford\tMustang\n'
# filename is: "/content/yolo_car_database/FordMustang/2018 Ford Mustang GT - Review & Road Test-lOA0HHPbrzU.info.json
# /content/yolo_car_database/FordMustang/2018_Ford_Mustang_GT__Review_&_Road_TestlOA0HHPbrzU.info.json
# filename is: "/content/yolo_car_database/FordMustang/SCARY Ford Mustang V8 Sound Compilation 2020!-_IFYFvS03gY.info.json
# /content/yolo_car_database/FordMustang/SCARY_Ford_Mustang_V8_Sound_Compilation_2020_IFYFvS03gY.info.json
# filename is: "/content/yolo_car_database/FordMustang/SCARY Ford Mustang V8 Sound Compilation 2020!-_IFYFvS03gY.jpg
# /content/yolo_car_database/FordMustang/SCARY_Ford_Mustang_V8_Sound_Compilation_2020_IFYFvS03gY.jpg
# filename is: "/content/yolo_car_database/FordMustang/SCARY Ford Mustang V8 Sound Compilation 2020!-_IFYFvS03gY.mp4
# /content/yolo_car_database/FordMustang/SCARY_Ford_Mustang_V8_Sound_Compilation_2020_IFYFvS03gY.mp4
# filename is: "/content/yolo_car_database/FordMustang/2018 Ford Mustang GT - Review & Road Test-lOA0HHPbrzU.webp
# /content/yolo_car_database/FordMustang/2018_Ford_Mustang_GT__Review_&_Road_TestlOA0HHPbrzU.webp
# filename is: "/content/yolo_car_database/FordMustang/AWD Trophy Truck Pulls a Wheelie Vs Ken Block’s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.jpg
# /content/yolo_car_database/FordMustang/AWD_Trophy_Truck_Pulls_a_Wheelie_Vs_Ken_Block’s_1,400hp_AWD_Ford_Mustang___Hoonicorn_Vs_the_WorldrhQBvsFAvCo.jpg
# filename is: "/content/yolo_car_database/FordMustang/AWD Trophy Truck Pulls a Wheelie Vs Ken Block’s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.mp4
# /content/yolo_car_database/FordMustang/AWD_Trophy_Truck_Pulls_a_Wheelie_Vs_Ken_Block’s_1,400hp_AWD_Ford_Mustang___Hoonicorn_Vs_the_WorldrhQBvsFAvCo.mp4
# filename is: "/content/yolo_car_database/FordMustang/2018 Ford Mustang GT - Review & Road Test-lOA0HHPbrzU.mp4
# /content/yolo_car_database/FordMustang/2018_Ford_Mustang_GT__Review_&_Road_TestlOA0HHPbrzU.mp4
# filename is: "/content/yolo_car_database/FordMustang/AWD Trophy Truck Pulls a Wheelie Vs Ken Block’s 1,400hp AWD Ford Mustang _ Hoonicorn Vs the World-rhQBvsFAvCo.info.json
# /content/yolo_car_database/FordMustang/AWD_Trophy_Truck_Pulls_a_Wheelie_Vs_Ken_Block’s_1,400hp_AWD_Ford_Mustang___Hoonicorn_Vs_the_WorldrhQBvsFAvCo.info.json
# filename is: "/content/yolo_car_database/FordMustang/2018 Ford Mustang GT - Review & Road Test-lOA0HHPbrzU.en.vtt
# /content/yolo_car_database/FordMustang/2018_Ford_Mustang_GT__Review_&_Road_TestlOA0HHPbrzU.en.vtt

# %% [markdown]
# # End of Scraping 200 car tyope video to Mega.nz Drive page

# %% [markdown]
# # The Below parts are for backup and don't need to be use, also maybe  some of the blow codes don not working!

# %%
# !ls /content/gdrive/My Drive/yolo_car_database
# Out:
# ls: cannot access '/content/gdrive/My': No such file or directory
# ls: cannot access 'Drive/yolo_car_database': No such file or directory

# %%
import urllib.request
from bs4 import BeautifulSoup
 
textToSearch = 'python tutorials'
query = urllib.parse.quote(textToSearch)
url = "https://www.youtube.com/results?search_query=" + query
response = urllib.request.urlopen(url)
html = response.read()
soup = BeautifulSoup(html, 'html.parser')
for vid in soup.findAll(attrs={'class':'yt-uix-tile-link'}):
    if not vid['href'].startswith("https://googleads.g.doubleclick.net/"):
        print('https://www.youtube.com' + vid['href'])

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt
 
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt'  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch2000:" "Ford Festiva" >> ford_video_list.txt 
 
# !echo '*****End of test 1 ******'

# %% [markdown]
# # I understand **HTTP Error 429 error** made because:
#
#  **The google don't like  too many request form one IP Address.**
#
# So tried to add these tags(` --rm-cache-dir --force-ipv4 --verbose `) to `youtube-dl` command as you can see below ( based of these reffrences [1][2] [2][3] [3][4]):
#
#  [1]: https://github.com/spectrico/vehicle-recognition-api-yolov4-python/blob/master/labels-makes.txt
#   [2]: https://askubuntu.com/questions/1220266/youtube-dl-do-not-working-http-error-429-too-many-requests-how-can-i-solve-this
#   [3]: https://forum.manjaro.org/t/youtube-dl-error-429-too-many-request/27150
#   [4]: https://stackoverflow.com/questions/59625386/how-could-we-solve-the-http-request-error-error-429-too-many-requests
#
# > Indented block

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt
 
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt' --rm-cache-dir --force-ipv4 --verbose  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch10:Ford Festiva"# >> ford_video_list.txt 
 
# !echo '*****End of test 1 ******'
# Out:
# Requirement already satisfied: youtube-dl in /usr/local/lib/python3.6/dist-packages (2020.11.12)
# [debug] System config: []
# [debug] User config: []
# [debug] Custom config: []
# [debug] Command-line args: ['--match-title', 'ford', '--add-metadata', '--write-thumbnail', '--list-thumbnails', '--mark-watched', '--write-info-json', 'ford_video_description_json.txt', '--write-description', 'ford_video_description.txt', '--rm-cache-dir', '--force-ipv4', '--verbose', '--cookies=Search-youtube-url-file.txt', '--ignore-errors', '--skip-download', '--get-url', '-f', 'bestvideo+bestaudio/best', '--default-search', 'ytsearch10:Ford Festiva#']
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2020.11.12
# [debug] Python version 3.6.9 (CPython) - Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# [debug] exe versions: ffmpeg 3.4.8, ffprobe 3.4.8
# [debug] Proxy map: {}
# *****End of test 1 ******

# %%
 
# !pip install youtube-search-python
from youtubesearchpython import SearchVideos
 
search = SearchVideos("NoCopyrightSounds", offset = 1, mode = "json", max_results = 20)
 
print(search.result())

# %%
# !youtube-dl "ytsearch1:how to create android app in app studio"
# Out:
# [download] Downloading playlist: how to create android app in app studio
# [youtube:search] query "how to create android app in app studio": Downloading page 1
# [youtube:search] playlist how to create android app in app studio: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] EOfCEhWq8sg: Downloading webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: How to Make an Android App for Beginners-EOfCEhWq8sg.f399.mp4
# [download]  93.2% of 72.94MiB at 27.48MiB/s ETA 00:00
# ERROR: Interrupted by user

# %%
# !pip install youtube-dl 
# !youtube-dl --default-search gvsearch5:how to develop for android --no-playlist --write-info-json --write-annotation --write-thumbnail --write-sub --skip-download 
# !youtube-dl --match-title 'ford' "ytsearch50":"Ford Festiva"+"peugeot 405"  --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]
Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Ford Festiva Camber Spacer Installation-36sAXUCzMjU.info.json
# [youtube] 36sAXUCzMjU: Downloading thumbnail ...
# [youtube] 36sAXUCzMjU: Writing thumbnail to: Ford Festiva Camber Spacer Installation-36sAXUCzMjU.webp
# [download] Ford Festiva Camber Spacer Installation-36sAXUCzMjU.mp4 has already been downloaded and merged
# [download] Downloading video 37 of 50
# [youtube] 8y8kVF9A_R4: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.info.json
# [youtube] 8y8kVF9A_R4: Downloading thumbnail ...
# [youtube] 8y8kVF9A_R4: Writing thumbnail to: 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.jpg
# [download] 1991 Ford Festiva Vaporizer-8y8kVF9A_R4.mp4 has already been downloaded and merged
# [download] Downloading video 38 of 50
# [download] "Festiva Fuel Pump Relay and Wiring" title did not match pattern "ford"
# [download] Downloading video 39 of 50
# [youtube] 7xaD45cVVeQ: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.info.json
# [youtube] 7xaD45cVVeQ: Downloading thumbnail ...
# [youtube] 7xaD45cVVeQ: Writing thumbnail to: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.jpg
# [download] Destination: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f135.mp4
# [download] 100% of 6.77MiB in 00:00
# [download] Destination: ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f140.m4a
# [download] 100% of 846.30KiB in 00:00
# [ffmpeg] Merging formats into "ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.mp4"
# Deleting original file ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f135.mp4 (pass -k to keep)
# Deleting original file ford festiva bp 1.8 dohc swap miata sephia for sold-7xaD45cVVeQ.f140.m4a (pass -k to keep)
# [download] Downloading video 40 of 50
# [youtube] 16LzO4ECzIE: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube] 16LzO4ECzIE: Downloading MPD manifest
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.info.json
# [youtube] 16LzO4ECzIE: Downloading thumbnail ...
# [youtube] 16LzO4ECzIE: Writing thumbnail to: 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.jpg
# [download] 1991 Ford Festiva Brake Light Upgrade-16LzO4ECzIE.mp4 has already been downloaded and merged
# [download] Downloading video 41 of 50
# [youtube] _tNbfZkBemE: Downloading webpage
# WARNING: video doesn't have subtitles
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: 100% electric car Ford Festiva  for sale  part 2 drive-_tNbfZkBemE.info.json
# [youtube] _tNbfZkBemE: Downloading thumbnail ...
# [youtube] _tNbfZkBemE: Writing thumbnail to: 100% electric car Ford Festiva  for sale  part 2 drive-_tNbfZkBemE.jpg
# [download] 100% electric car Ford Festiva  for sale  part 2 drive-_tNbfZkBemE.mp4 has already been downloaded and merged
# [download] Downloading video 42 of 50
# [youtube] tT0FkSQ0ULA: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Liam's In-Depths #14 - 1999 Ford Festiva GLXi Demon-AY6_82ETnCU.info.json
# [youtube] AY6_82ETnCU: Downloading thumbnail ...
# WARNING: Unable to download thumbnail "https://i.ytimg.com/vi_webp/AY6_82ETnCU/maxresdefault.webp": HTTP Error 404: Not Found
# [download] Liam's In-Depths #14 - 1999 Ford Festiva GLXi Demon-AY6_82ETnCU.mp4 has already been downloaded and merged
# [download] Downloading video 50 of 50
# [youtube] Fqrqqb3H43U: Downloading webpage
# WARNING: video doesn't have subtitles
# [youtube] Fqrqqb3H43U: Downloading MPD manifest
# WARNING: There are no annotations to write.
# [info] Writing video description metadata as JSON to: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.info.json
# [youtube] Fqrqqb3H43U: Downloading thumbnail ...
# [youtube] Fqrqqb3H43U: Writing thumbnail to: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.jpg
# [dashsegments] Total fragments: 16
# [download] Destination: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f135.mp4
# [download] 100% of 7.32MiB in 00:08
# [dashsegments] Total fragments: 9
# [download] Destination: Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f140.m4a
# [download] 100% of 937.12KiB in 00:04
# [ffmpeg] Merging formats into "Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.mp4"
# Deleting original file Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f135.mp4 (pass -k to keep)
# Deleting original file Crazy V8 Ford Festiva BURNOUT!!!-Fqrqqb3H43U.f140.m4a (pass -k to keep)
# [download] Finished downloading playlist: Ford Festiva

# %%
# !pip install youtube-dl 
# %cd '/content/'

import os
try:
    os.remove('/content/yolo_car_database')
except OSError:
    pass

# !rm -rf '/content/yolo_car_database'
# !mkdir '/content/yolo_car_database'
# %cd '/content/yolo_car_database'
# !echo 't' >> t.txt
# !pwd 
# !ls
# !youtube-dl --default-search gvsearch5:how to develop for android --no-playlist --write-info-json --write-annotation --write-thumbnail --write-sub --skip-download 
# !youtube-dl --match-title 'ford ' "ytsearch50":"Ford Festiva"+"peugeot 405"  --write-info-json --write-annotation --write-thumbnail --write-sub -f 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4'

# !rm -rf "/content/gdrive/My Drive/yolo_car_databe" && mkdir "/content/gdrive/My Drive/yolo_car_databe"

# !cp -r '/content/yolo_car_database' "/content/gdrive/My Drive/"

# %%
# !ls '/content/yolo_car_database2'

# %%
# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails  --rm-cache-dir --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best  --default-search "ytsearch10:Ford Festiva"# >> ford_video_list.txt

# %%
# !pip install youtube-dl
# !echo '' > ford_video_list.txt
# !chmod 755 ford_video_list.txt

# !youtube-dl --match-title 'ford' --add-metadata --write-thumbnail --list-thumbnails    --mark-watched --write-info-json 'ford_video_description_json.txt' --write-description 'ford_video_description.txt'  --cookies='Search-youtube-url-file.txt' --ignore-errors  --skip-download --get-url -f bestvideo+bestaudio/best --default-search "ytsearch50:" "Ford Festiva" >> ford_video_list.txt 

# !echo '*****End of test 1 ******'
